# %%
import pandas as pd 
dt = pd.read_csv("covid19_confirmed.csv")
dt2 = pd.read_csv("Global_Mobility_Report.csv")
# Out:
# c:\work\py3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Covid19_confirmed data preprocessing

# %%
usc = dt[dt['Country/Region'] == 'US']
usc = pd.melt(usc, id_vars='Country/Region', value_vars=usc.iloc[:,4:],
        var_name='date', value_name='confirmed_cases')
usc['date'] = pd.to_datetime(usc.date)
usc = usc.rename(columns={'Country/Region':'Country'})
usc.tail(3)
# Out:
#     Country       date  confirmed_cases
# 135      US 2020-06-05          1897380
# 136      US 2020-06-06          1920061
# 137      US 2020-06-07          1942363

# %%
len(usc)
# Out:
# 138

# %%
def pltfunc(x,y,data,xlabel=None):
    fig, ax = plt.subplots()
    _=ax.plot(x,y,data =data)
    import matplotlib.dates as mdates
    months = mdates.MonthLocator()
    ax.xaxis.set_major_locator(months)
    ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
    ax.format_ydata = lambda x: '$%1.2f' % x  # format the price.
    ax.grid(True)

    # rotates and right aligns the x labels, and moves the bottom of the
    # axes up to make room for them
    fig.autofmt_xdate()
    _=plt.xlabel(xlabel)
    
pltfunc('date', 'confirmed_cases', usc,"Date from 2020-01-22 to 2020-06-07")

# %%
# _ = plt.plot(usc1.index,usc1['confirmed_cases'])
# _ = plt.title('confirmed cases')
# #_= plt.xticks(usc['month'])
# _ = plt.xlabel("Date from 2020-01-22 to 2020-05-28")
# #_ = plt.xticks(rotation='vertical')

# %%
usc['month'] = pd.DatetimeIndex(usc['date']).month
usc2 = round(usc.groupby(['Country','month']).mean(),2)
usc2 = usc2.reset_index()
usc2
# Out:
#   Country  month  confirmed_cases
# 0      US      1             3.80
# 1      US      2            21.45
# 2      US      3         35097.42
# 3      US      4        650783.47
# 4      US      5       1458511.87
# 5      US      6       1875260.71

# %%
_=sns.barplot(x=usc['month'], y=usc['confirmed_cases'] , palette="RdBu_r")

# %% [markdown]
# # US-counties Covid-19 Confirmed

# %%
df1 = pd.read_csv('us-counties.csv')
df1.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
df1.tail()
# Out:
#               date      county    state     fips  cases  deaths
# 212601  2020-06-06  Sweetwater  Wyoming  56037.0     32       0
# 212602  2020-06-06       Teton  Wyoming  56039.0    100       1
# 212603  2020-06-06       Uinta  Wyoming  56041.0     19       0
# 212604  2020-06-06    Washakie  Wyoming  56043.0     38       3
# 212605  2020-06-06      Weston  Wyoming  56045.0      1       0

# %%
df1.state.unique()
# Out:
# array(['Washington', 'Illinois', 'California', 'Arizona', 'Massachusetts',
#        'Wisconsin', 'Texas', 'Nebraska', 'Utah', 'Oregon', 'Florida',
#        'New York', 'Rhode Island', 'Georgia', 'New Hampshire',
#        'North Carolina', 'New Jersey', 'Colorado', 'Maryland', 'Nevada',
#        'Tennessee', 'Hawaii', 'Indiana', 'Kentucky', 'Minnesota',
#        'Oklahoma', 'Pennsylvania', 'South Carolina',
#        'District of Columbia', 'Kansas', 'Missouri', 'Vermont',
#        'Virginia', 'Connecticut', 'Iowa', 'Louisiana', 'Ohio', 'Michigan',
#        'South Dakota', 'Arkansas', 'Delaware', 'Mississippi',
#        'New Mexico', 'North Dakota', 'Wyoming', 'Alaska', 'Maine',
#        'Alabama', 'Idaho', 'Montana', 'Puerto Rico', 'Virgin Islands',
#        'Guam', 'West Virginia', 'Northern Mariana Islands'], dtype=object)

# %%
slst = ['New York', 'New Jersey','California','Illinois','Massachusetts']
ny = df1[df1.state=='New York']
pltfunc('date', 'cases', ny,"Date from 2020-01-22 to 2020-06-06")

# %%
k = ny.groupby(['state','date']).cases.sum()
k = k.reset_index()
k
# Out:
#        state        date   cases
# 0   New York  2020-03-01       1
# 1   New York  2020-03-02       1
# 2   New York  2020-03-03       2
# 3   New York  2020-03-04      11
# 4   New York  2020-03-05      22
# ..       ...         ...     ...
# 93  New York  2020-06-02  377881
# 94  New York  2020-06-03  378924
# 95  New York  2020-06-04  379977
# 96  New York  2020-06-05  381019
# 97  New York  2020-06-06  382102
#
# [98 rows x 3 columns]

# %%
k['date'] = pd.to_datetime(k.date)

# %%
dt = k.cases
lst = []
for i in range(97,0,-1):
    lst.append(dt[i]-dt[i-1])
lst.append(1)
k['daily_cases'] = lst[::-1]
k.describe()
# Out:
#                cases   daily_cases
# count      98.000000     98.000000
# mean   203295.591837   3899.000000
# std    147854.562726   3455.947227
# min         1.000000      0.000000
# 25%     34602.250000   1111.000000
# 50%    243641.500000   2730.500000
# 75%    345297.250000   6255.250000
# max    382102.000000  12237.000000

# %%
import matplotlib.dates as mdates
months = mdates.MonthLocator()
def pltfunc2(x,y,data,xlabel=None,title=None):
    fig, ax = plt.subplots()
    _=ax.plot(x,y,data =data)
    ax.xaxis.set_major_locator(months)
    ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
    ax.format_ydata = lambda x: '$%1.2f' % x  # format the price.
    ax.grid(True)

    # rotates and right aligns the x labels, and moves the bottom of the
    # axes up to make room for them
    fig.autofmt_xdate()
    _=plt.xlabel(xlabel)
    _=plt.title(title)
    
# pltfunc2('date', 'confirmed_cases', usc,"Date from 2020-01-22 to 2020-06-07")

# %%
import matplotlib.dates as mdates
months = mdates.MonthLocator()
fig, ax = plt.subplots(2,2,figsize=(12,9))
color = ['blue','orange','green','red','purple']
for j in range(len(slst)):
    statelist = df1[df1.state==slst[j]]
    k = statelist.groupby(['state','date']).cases.sum()
    k = k.reset_index()
    k['date'] = pd.to_datetime(k.date)
    dt = k.cases
    lst = []
    for i in range(len(k)-1,0,-1):
        lst.append(dt[i]-dt[i-1])
    lst.append(1)
    k['daily_cases'] = lst[::-1]
    #_=ax.scatter('date', 'daily_cases',data =k)
    if j == 0:
        t = 'ax[0,0]'
    elif j ==1:
        t = 'ax[0,1]'
    elif j == 2:
        t = 'ax[1,0]'
    elif j == 3:
        t = 'ax[1,1]'
    else:
        fig, ax = plt.subplots()
        t = 'ax'
    p = eval(t)
    p.plot('date', 'daily_cases',data =k,color=color[j])
    p.format_xdata = mdates.DateFormatter('%Y-%m-%d')
    p.format_ydata = lambda x: '$%1.2f' % x  # format the price.
    p.grid(True)
    fig.autofmt_xdate()
    p.set_title(slst[j])
    

#pltfunc2('date', 'daily_cases', k,title = j)

# %%
import matplotlib.dates as mdates
months = mdates.MonthLocator()
color = ['blue','orange','green','red','purple']
fig, ax = plt.subplots(figsize=(12, 9))
for j in range(len(slst)):
    statelist = df1[df1.state==slst[j]]
    k = statelist.groupby(['state','date']).cases.sum()
    k = k.reset_index()
    k['date'] = pd.to_datetime(k.date)
    dt = k.cases
    lst = []
    for i in range(len(k)-1,0,-1):
        lst.append(dt[i]-dt[i-1])
    lst.append(1)
    k['daily_cases'] = lst[::-1]
    _=ax.scatter('date', 'daily_cases',data =k)
    _=ax.plot('date', 'daily_cases',data =k, color = color[j])
ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
ax.format_ydata = lambda x: '$%1.2f' % x  # format the price.
ax.grid(True)
fig.autofmt_xdate()

# %%
slst = ['New York', 'New Jersey','California','Illinois','Massachusetts']
fivestatecases = df1[df1.state.isin(slst)]
t = fivestatecases.groupby(['state','date']).cases.sum()
t = t.reset_index()
t['date'] = pd.to_datetime(t.date)
dt = t.cases
lst = []
for i in range(len(t)-1,0,-1):
    lst.append(dt[i]-dt[i-1])
lst.append(1)
t['daily_cases'] = lst[::-1]
fivestatecases = t
fivestatecases.shape
# Out:
# (589, 4)

# %% [markdown]
# ## Global_Mobility_Report data preprocessing

# %%
dt2.head(3)
# Out:
#   country_region_code        country_region sub_region_1 sub_region_2  \
# 0                  AE  United Arab Emirates          NaN          NaN
# 1                  AE  United Arab Emirates          NaN          NaN
# 2                  AE  United Arab Emirates          NaN          NaN
#
#          date  retail_and_recreation_percent_change_from_baseline  \
# 0  2020-02-15                                                0.0
# 1  2020-02-16                                                1.0
# 2  2020-02-17                                               -1.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                4.0
# 1                                                4.0
# 2                                                1.0
#
#    parks_percent_change_from_baseline  \
# 0                                 5.0
# 1                                 4.0
# 2                                 5.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            0.0
# 1                                            1.0
# 2                                            1.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      2.0
# 1                                      2.0
# 2                                      2.0
#
#    residential_percent_change_from_baseline
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0

# %%
usm = dt2[dt2['country_region']=='United States']
usm.head(3)
# Out:
#        country_region_code country_region sub_region_1 sub_region_2  \
# 184064                  US  United States          NaN          NaN
# 184065                  US  United States          NaN          NaN
# 184066                  US  United States          NaN          NaN
#
#               date  retail_and_recreation_percent_change_from_baseline  \
# 184064  2020-02-15                                                6.0
# 184065  2020-02-16                                                7.0
# 184066  2020-02-17                                                6.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 184064                                                2.0
# 184065                                                1.0
# 184066                                                0.0
#
#         parks_percent_change_from_baseline  \
# 184064                                15.0
# 184065                                16.0
# 184066                                28.0
#
#         transit_stations_percent_change_from_baseline  \
# 184064                                            3.0
# 184065                                            2.0
# 184066                                           -9.0
#
#         workplaces_percent_change_from_baseline  \
# 184064                                      2.0
# 184065                                      0.0
# 184066                                    -24.0
#
#         residential_percent_change_from_baseline
# 184064                                      -1.0
# 184065                                      -1.0
# 184066                                       5.0

# %%
usm.sub_region_1.unique()
# Out:
# array([nan, 'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
ca = usm[usm.sub_region_1=='California']
ca.tail()
# Out:
#        country_region_code country_region sub_region_1 sub_region_2  \
# 206793                  US  United States   California  Yuba County
# 206794                  US  United States   California  Yuba County
# 206795                  US  United States   California  Yuba County
# 206796                  US  United States   California  Yuba County
# 206797                  US  United States   California  Yuba County
#
#               date  retail_and_recreation_percent_change_from_baseline  \
# 206793  2020-05-25                                               21.0
# 206794  2020-05-26                                               23.0
# 206795  2020-05-27                                               21.0
# 206796  2020-05-28                                               20.0
# 206797  2020-05-29                                               20.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 206793                                               20.0
# 206794                                               11.0
# 206795                                               14.0
# 206796                                               17.0
# 206797                                               17.0
#
#         parks_percent_change_from_baseline  \
# 206793                                 NaN
# 206794                                 NaN
# 206795                                 NaN
# 206796                                 NaN
# 206797                                94.0
#
#         transit_stations_percent_change_from_baseline  \
# 206793                                          -26.0
# 206794                                           -9.0
# 206795                                          -15.0
# 206796                                          -12.0
# 206797                                          -10.0
#
#         workplaces_percent_change_from_baseline  \
# 206793                                    -66.0
# 206794                                    -30.0
# 206795                                    -31.0
# 206796                                    -31.0
# 206797                                    -27.0
#
#         residential_percent_change_from_baseline
# 206793                                      15.0
# 206794                                       9.0
# 206795                                       9.0
# 206796                                       9.0
# 206797                                      10.0

# %%
usm = usm.rename(columns={'sub_region_1':'state'})

# %%
usm = round(usm.groupby(['state','date']).mean(),2)
usm = usm.reset_index()
#usm = usm.rename(columns={'country_region_code':'Country'})
usm.head()
# Out:
#      state        date  retail_and_recreation_percent_change_from_baseline  \
# 0  Alabama  2020-02-15                                               5.16
# 1  Alabama  2020-02-16                                              -1.45
# 2  Alabama  2020-02-17                                              -1.17
# 3  Alabama  2020-02-18                                              -4.28
# 4  Alabama  2020-02-19                                               1.44
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               0.23
# 1                                              -4.02
# 2                                              -4.48
# 3                                              -5.00
# 4                                              -0.73
#
#    parks_percent_change_from_baseline  \
# 0                               49.57
# 1                               -5.48
# 2                               12.93
# 3                              -12.47
# 4                                6.67
#
#    transit_stations_percent_change_from_baseline  \
# 0                                           5.76
# 1                                           2.14
# 2                                           5.73
# 3                                          -0.68
# 4                                           3.71
#
#    workplaces_percent_change_from_baseline  \
# 0                                     0.78
# 1                                    -1.92
# 2                                   -16.26
# 3                                     0.34
# 4                                     1.40
#
#    residential_percent_change_from_baseline
# 0                                     -0.86
# 1                                      0.52
# 2                                      4.33
# 3                                      1.44
# 4                                      0.00

# %%
usm['date']=pd.to_datetime(usm.date)
usm.head(3)
# Out:
#      state       date  retail_and_recreation_percent_change_from_baseline  \
# 0  Alabama 2020-02-15                                               5.16
# 1  Alabama 2020-02-16                                              -1.45
# 2  Alabama 2020-02-17                                              -1.17
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               0.23
# 1                                              -4.02
# 2                                              -4.48
#
#    parks_percent_change_from_baseline  \
# 0                               49.57
# 1                               -5.48
# 2                               12.93
#
#    transit_stations_percent_change_from_baseline  \
# 0                                           5.76
# 1                                           2.14
# 2                                           5.73
#
#    workplaces_percent_change_from_baseline  \
# 0                                     0.78
# 1                                    -1.92
# 2                                   -16.26
#
#    residential_percent_change_from_baseline
# 0                                     -0.86
# 1                                      0.52
# 2                                      4.33

# %%
slst = ['New York', 'New Jersey','California','Illinois','Massachusetts']
fivedf = usm[usm.state.isin(slst)]
len(fivedf),len(fivestatecases)
# Out:
# (525, 589)

# %%
fivedf.date.unique(),fivestatecases.date.unique()
# Out:
# (array(['2020-02-15T00:00:00.000000000', '2020-02-16T00:00:00.000000000',
#         '2020-02-17T00:00:00.000000000', '2020-02-18T00:00:00.000000000',
#         '2020-02-19T00:00:00.000000000', '2020-02-20T00:00:00.000000000',
#         '2020-02-21T00:00:00.000000000', '2020-02-22T00:00:00.000000000',
#         '2020-02-23T00:00:00.000000000', '2020-02-24T00:00:00.000000000',
#         '2020-02-25T00:00:00.000000000', '2020-02-26T00:00:00.000000000',
#         '2020-02-27T00:00:00.000000000', '2020-02-28T00:00:00.000000000',
#         '2020-02-29T00:00:00.000000000', '2020-03-01T00:00:00.000000000',
#         '2020-03-02T00:00:00.000000000', '2020-03-03T00:00:00.000000000',
#         '2020-03-04T00:00:00.000000000', '2020-03-05T00:00:00.000000000',
#         '2020-03-06T00:00:00.000000000', '2020-03-07T00:00:00.000000000',
#         '2020-03-08T00:00:00.000000000', '2020-03-09T00:00:00.000000000',
#         '2020-03-10T00:00:00.000000000', '2020-03-11T00:00:00.000000000',
#         '2020-04-08T00:00:00.000000000', '2020-04-09T00:00:00.000000000',
#         '2020-04-10T00:00:00.000000000', '2020-04-11T00:00:00.000000000',
#         '2020-04-12T00:00:00.000000000', '2020-04-13T00:00:00.000000000',
#         '2020-04-14T00:00:00.000000000', '2020-04-15T00:00:00.000000000',
#         '2020-04-16T00:00:00.000000000', '2020-04-17T00:00:00.000000000',
#         '2020-04-18T00:00:00.000000000', '2020-04-19T00:00:00.000000000',
#         '2020-04-20T00:00:00.000000000', '2020-04-21T00:00:00.000000000',
#         '2020-04-22T00:00:00.000000000', '2020-04-23T00:00:00.000000000',
#         '2020-04-24T00:00:00.000000000', '2020-04-25T00:00:00.000000000',
#         '2020-04-26T00:00:00.000000000', '2020-04-27T00:00:00.000000000',
#         '2020-04-28T00:00:00.000000000', '2020-04-29T00:00:00.000000000',
#         '2020-04-30T00:00:00.000000000', '2020-05-01T00:00:00.000000000',
#         '2020-05-02T00:00:00.000000000', '2020-05-03T00:00:00.000000000',
#         '2020-05-04T00:00:00.000000000', '2020-05-05T00:00:00.000000000',
#         '2020-05-06T00:00:00.000000000', '2020-05-07T00:00:00.000000000',
#         '2020-05-08T00:00:00.000000000', '2020-05-09T00:00:00.000000000',
#         '2020-05-10T00:00:00.000000000', '2020-05-11T00:00:00.000000000',
#         '2020-05-12T00:00:00.000000000', '2020-05-13T00:00:00.000000000',
#         '2020-05-14T00:00:00.000000000', '2020-05-15T00:00:00.000000000',
#         '2020-05-16T00:00:00.000000000', '2020-05-17T00:00:00.000000000',
#         '2020-05-18T00:00:00.000000000', '2020-05-19T00:00:00.000000000',
#         '2020-05-20T00:00:00.000000000', '2020-05-21T00:00:00.000000000',
#         '2020-05-22T00:00:00.000000000', '2020-05-23T00:00:00.000000000',
#         '2020-05-24T00:00:00.000000000', '2020-05-25T00:00:00.000000000',
#         '2020-05-26T00:00:00.000000000', '2020-05-27T00:00:00.000000000',
#         '2020-05-28T00:00:00.000000000', '2020-05-29T00:00:00.000000000',
#         '2020-05-30T00:00:00.000000000', '2020-05-31T00:00:00.000000000',
#         '2020-06-01T00:00:00.000000000', '2020-06-02T00:00:00.000000000',
#         '2020-06-03T00:00:00.000000000', '2020-06-04T00:00:00.000000000',
#         '2020-06-05T00:00:00.000000000', '2020-06-06T00:00:00.000000000',
#         '2020-01-24T00:00:00.000000000'], dtype='datetime64[ns]'))

# %% [markdown]
# ## Merge 2 datasets

# %%
df =pd.merge(fivedf,fivestatecases,how='inner',on=['state','date'])

# %%
df.head()
# Out:
#         state       date  retail_and_recreation_percent_change_from_baseline  \
# 0  California 2020-02-15                                               6.34
# 1  California 2020-02-16                                              14.07
# 2  California 2020-02-17                                              11.57
# 3  California 2020-02-18                                               2.70
# 4  California 2020-02-19                                               2.95
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               4.50
# 1                                               7.25
# 2                                               1.73
# 3                                               2.35
# 4                                               1.57
#
#    parks_percent_change_from_baseline  \
# 0                               30.73
# 1                               55.51
# 2                               60.56
# 3                               24.90
# 4                               20.98
#
#    transit_stations_percent_change_from_baseline  \
# 0                                           5.36
# 1                                           6.72
# 2                                          -6.07
# 3                                           3.44
# 4                                           1.10
#
#    workplaces_percent_change_from_baseline  \
# 0                                    -1.76
# 1                                    -0.69
# 2                                   -38.47
# 3                                    -1.33
# 4                                    -1.53
#
#    residential_percent_change_from_baseline  cases  daily_cases
# 0                                     -0.60      7            0
# 1                                     -1.39      7            0
# 2                                      7.49      7            0
# 3                                     -0.06      7            0
# 4                                      0.19      7            0

# %%
df.shape
# Out:
# (492, 10)

# %%
df.columns
df =df.drop(['month'],axis=1)

# %%
df.columns =['state', 'date', 
       'retail_and_recreation','grocery_and_pharmacy',
       'parks','transit_stations','workplaces','residential','cumulated_cases','new_cases']
df.head()
# Out:
#         state       date  retail_and_recreation  grocery_and_pharmacy  parks  \
# 0  California 2020-02-15                   6.34                  4.50  30.73
# 1  California 2020-02-16                  14.07                  7.25  55.51
# 2  California 2020-02-17                  11.57                  1.73  60.56
# 3  California 2020-02-18                   2.70                  2.35  24.90
# 4  California 2020-02-19                   2.95                  1.57  20.98
#
#    transit_stations  workplaces  residential  cumulated_cases  new_cases
# 0              5.36       -1.76        -0.60                7          0
# 1              6.72       -0.69        -1.39                7          0
# 2             -6.07      -38.47         7.49                7          0
# 3              3.44       -1.33        -0.06                7          0
# 4              1.10       -1.53         0.19                7          0

# %%
df1 = df.groupby(['date']).mean().reset_index()
df1.head()
# Out:
#         date  retail_and_recreation  grocery_and_pharmacy      parks  \
# 0 2020-02-15               5.756667              1.523333  15.946667
# 1 2020-02-16              10.443333              2.550000  27.443333
# 2 2020-02-17               7.830000             -0.743333  30.100000
# 3 2020-02-18               0.240000             -2.210000   3.370000
# 4 2020-02-19               2.813333             -0.806667   9.603333
#
#    transit_stations  workplaces  residential  cumulated_cases  new_cases
# 0          4.486667   -0.476667    -0.576667         3.333333        0.0
# 1          4.040000    0.650000    -1.093333         3.333333        0.0
# 2         -9.836667  -32.220000     7.016667         3.333333        0.0
# 3          0.326667   -2.636667     1.120000         3.333333        0.0
# 4          0.230000   -2.480000     0.723333         3.333333        0.0

# %%
cor = df1.iloc[:,1:].corr()
cor
# Out:
#                        retail_and_recreation  grocery_and_pharmacy     parks  \
# retail_and_recreation               1.000000              0.761623  0.278168
# grocery_and_pharmacy                0.761623              1.000000  0.364527
# parks                               0.278168              0.364527  1.000000
# transit_stations                    0.985587              0.729845  0.298932
# workplaces                          0.904348              0.673233  0.209328
# residential                        -0.897600             -0.637719 -0.309287
# cumulated_cases                    -0.499550             -0.282348  0.354067
# new_cases                          -0.883116             -0.718187 -0.262621
#
#                        transit_stations  workplaces  residential  \
# retail_and_recreation          0.985587    0.904348    -0.897600
# grocery_and_pharmacy           0.729845    0.673233    -0.637719
# parks                          0.298932    0.209328    -0.309287
# transit_stations               1.000000    0.938069    -0.928690
# workplaces                     0.938069    1.000000    -0.977680
# residential                   -0.928690   -0.977680     1.000000
# cumulated_cases               -0.493080   -0.555783     0.488335
# new_cases                     -0.882560   -0.822624     0.819609
#
#                        cumulated_cases  new_cases
# retail_and_recreation        -0.499550  -0.883116
# grocery_and_pharmacy         -0.282348  -0.718187
# parks                         0.354067  -0.262621
# transit_stations             -0.493080  -0.882560
# workplaces                   -0.555783  -0.822624
# residential                   0.488335   0.819609
# cumulated_cases               1.000000   0.460175
# new_cases                     0.460175   1.000000

# %%
f, ax = plt.subplots(figsize=(12, 9))
hm = sns.heatmap(round(cor,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f',
                 linewidths=.05)
f.subplots_adjust(top=0.93)
t= f.suptitle('Moblitiy rate and Covid-19 cases correlation in USA', fontsize=14)

# %%
import matplotlib.dates as mdates
months = mdates.MonthLocator()
color = ['blue','orange','green','red','purple']

# %%
df = df[df.new_cases>=0]
df.describe()
# Out:
#        retail_and_recreation  grocery_and_pharmacy       parks  \
# count             490.000000            490.000000  490.000000
# mean              -29.005673             -4.705816   22.126857
# std                22.099981             13.507287   42.379859
# min               -74.640000            -51.850000  -58.340000
# 25%               -44.505000            -13.652500  -10.427500
# 50%               -36.680000             -4.780000   16.120000
# 75%               -18.955000              3.495000   46.482500
# max                26.640000             40.740000  169.310000
#
#        transit_stations  workplaces  residential  cumulated_cases  \
# count        490.000000  490.000000   490.000000       490.000000
# mean         -30.051041  -31.793816    13.304082     67999.581633
# std           20.615082   20.089315     8.493416     93366.735044
# min          -65.690000  -74.500000    -3.330000         1.000000
# 25%          -46.475000  -46.750000     7.497500       422.500000
# 50%          -34.265000  -37.750000    14.990000     31862.500000
# 75%          -15.310000  -21.365000    19.747500     92598.500000
# max           15.900000    5.500000    30.730000    373108.000000
#
#           new_cases
# count    490.000000
# mean    1739.365306
# std     2120.710043
# min        0.000000
# 25%      110.500000
# 50%     1267.500000
# 75%     2216.000000
# max    12237.000000

# %%
_ = plt.plot(range(0,97),df['retail_and_recreation'])
_ = plt.title('retail_and_recreation')
_ = plt.xlabel("Date from 2020-02-15 to 2020-05-28")
_ = plt.ylabel("percentage")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-268-12c32b6a513c> in <module>
# ----> 1 _ = plt.plot(range(0,97),df['retail_and_recreation'])
#       2 _ = plt.title('retail_and_recreation')
#       3 _ = plt.xlabel("Date from 2020-02-15 to 2020-05-28")
#       4 _ = plt.ylabel("percentage")
#
# c:\work\py3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# c:\work\py3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
#    1648             self.add_line(line)
#
# c:\work\py3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# c:\work\py3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (97,) and (492,)

# %%
_ = plt.plot(range(0,97),df['grocery_and_pharmacy'])
_ = plt.title('grocery_and_pharmacy')
_ = plt.xlabel("Date from 2020-02-15 to 2020-05-28")
_ = plt.ylabel("percentage")

# %%
_ = plt.plot(range(0,97),df['parks'])
_ = plt.title('parks')
_ = plt.xlabel("Date from 2020-02-15 to 2020-05-28")
_ = plt.ylabel("percentage")

# %%
_ = plt.plot(range(0,97),df['transit_stations'])
_ = plt.title('transit_stations')
_ = plt.xlabel("Date from 2020-02-15 to 2020-05-28")
_ = plt.ylabel("percentage")

# %%
_ = plt.plot(range(0,97),df['workplaces'])
_ = plt.title('workplaces')
_ = plt.xlabel("Date from 2020-02-15 to 2020-05-28")
_ = plt.ylabel("percentage")

# %%
_ = plt.plot(range(0,97),df['residential'])
_ = plt.title('residential')
_ = plt.xlabel("Date from 2020-02-15 to 2020-05-28")
_ = plt.ylabel("percentage")

# %%
df.to_csv('processed_dt')

# %%
df.head()
# Out:
#         state       date  retail_and_recreation  grocery_and_pharmacy  parks  \
# 0  California 2020-02-15                   6.34                  4.50  30.73
# 1  California 2020-02-16                  14.07                  7.25  55.51
# 2  California 2020-02-17                  11.57                  1.73  60.56
# 3  California 2020-02-18                   2.70                  2.35  24.90
# 4  California 2020-02-19                   2.95                  1.57  20.98
#
#    transit_stations  workplaces  residential  cumulated_cases  new_cases
# 0              5.36       -1.76        -0.60                7          0
# 1              6.72       -0.69        -1.39                7          0
# 2             -6.07      -38.47         7.49                7          0
# 3              3.44       -1.33        -0.06                7          0
# 4              1.10       -1.53         0.19                7          0
