# %%
import pandas as pd 
dt = pd.read_csv("covid19_confirmed.csv")
dt2 = pd.read_csv("Global_Mobility_Report.csv")
# Out:
# /Users/irenecho/work/venv/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Covid19_confirmed data preprocessing

# %%
usc = dt[dt['Country/Region'] == 'US']
usc = pd.melt(usc, id_vars='Country/Region', value_vars=usc.iloc[:,4:],
        var_name='date', value_name='confirmed_cases')
usc['date'] = pd.to_datetime(usc.date)
usc = usc.rename(columns={'Country/Region':'Country'})
usc.tail(3)
# Out:
#     Country       date  confirmed_cases
# 135      US 2020-06-05          1897380
# 136      US 2020-06-06          1920061
# 137      US 2020-06-07          1942363

# %%
len(usc)
# Out:
# 138

# %%
def pltfunc(x,y,data,xlabel=None):
    fig, ax = plt.subplots()
    _=ax.plot(x,y,data =data)
    import matplotlib.dates as mdates
    months = mdates.MonthLocator()
    ax.xaxis.set_major_locator(months)
    ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
    ax.format_ydata = lambda x: '$%1.2f' % x  # format the price.
    ax.grid(True)

    # rotates and right aligns the x labels, and moves the bottom of the
    # axes up to make room for them
    fig.autofmt_xdate()
    _=plt.xlabel(xlabel)
    
pltfunc('date', 'confirmed_cases', usc,"Date from 2020-01-22 to 2020-06-07")

# %%
usc['month'] = pd.DatetimeIndex(usc['date']).month
usc2 = round(usc.groupby(['Country','month']).mean(),2)
usc2 = usc2.reset_index()
usc2
# Out:
#   Country  month  confirmed_cases
# 0      US      1             3.80
# 1      US      2            21.45
# 2      US      3         35097.42
# 3      US      4        650783.47
# 4      US      5       1458511.87
# 5      US      6       1875260.71

# %%
_=sns.barplot(x=usc['month'], y=usc['confirmed_cases'] , palette="RdBu_r")

# %% [markdown]
# # US-counties Covid-19 Confirmed

# %%
df1 = pd.read_csv('us-counties.csv')
df1.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %%
df1.tail()
# Out:
#               date      county    state     fips  cases  deaths
# 212601  2020-06-06  Sweetwater  Wyoming  56037.0     32       0
# 212602  2020-06-06       Teton  Wyoming  56039.0    100       1
# 212603  2020-06-06       Uinta  Wyoming  56041.0     19       0
# 212604  2020-06-06    Washakie  Wyoming  56043.0     38       3
# 212605  2020-06-06      Weston  Wyoming  56045.0      1       0

# %%
df1.state.unique()
# Out:
# array(['Washington', 'Illinois', 'California', 'Arizona', 'Massachusetts',
#        'Wisconsin', 'Texas', 'Nebraska', 'Utah', 'Oregon', 'Florida',
#        'New York', 'Rhode Island', 'Georgia', 'New Hampshire',
#        'North Carolina', 'New Jersey', 'Colorado', 'Maryland', 'Nevada',
#        'Tennessee', 'Hawaii', 'Indiana', 'Kentucky', 'Minnesota',
#        'Oklahoma', 'Pennsylvania', 'South Carolina',
#        'District of Columbia', 'Kansas', 'Missouri', 'Vermont',
#        'Virginia', 'Connecticut', 'Iowa', 'Louisiana', 'Ohio', 'Michigan',
#        'South Dakota', 'Arkansas', 'Delaware', 'Mississippi',
#        'New Mexico', 'North Dakota', 'Wyoming', 'Alaska', 'Maine',
#        'Alabama', 'Idaho', 'Montana', 'Puerto Rico', 'Virgin Islands',
#        'Guam', 'West Virginia', 'Northern Mariana Islands'], dtype=object)

# %%
slst = ['New York', 'New Jersey','California','Illinois','Massachusetts']
ny = df1[df1.state=='New York']
pltfunc('date', 'cases', ny,"Date from 2020-01-22 to 2020-06-06")

# %%
k = ny.groupby(['state','date']).cases.sum()
k = k.reset_index()
k
# Out:
#        state        date   cases
# 0   New York  2020-03-01       1
# 1   New York  2020-03-02       1
# 2   New York  2020-03-03       2
# 3   New York  2020-03-04      11
# 4   New York  2020-03-05      22
# ..       ...         ...     ...
# 93  New York  2020-06-02  377881
# 94  New York  2020-06-03  378924
# 95  New York  2020-06-04  379977
# 96  New York  2020-06-05  381019
# 97  New York  2020-06-06  382102
#
# [98 rows x 3 columns]

# %%
k['date'] = pd.to_datetime(k.date)

# %%
dt = k.cases
lst = []
for i in range(97,0,-1):
    lst.append(dt[i]-dt[i-1])
lst.append(1)
k['daily_cases'] = lst[::-1]
k.describe()
# Out:
#                cases   daily_cases
# count      98.000000     98.000000
# mean   203295.591837   3899.000000
# std    147854.562726   3455.947227
# min         1.000000      0.000000
# 25%     34602.250000   1111.000000
# 50%    243641.500000   2730.500000
# 75%    345297.250000   6255.250000
# max    382102.000000  12237.000000

# %%
k.head()
# Out:
#       state       date  cases  daily_cases
# 0  New York 2020-03-01      1            1
# 1  New York 2020-03-02      1            0
# 2  New York 2020-03-03      2            1
# 3  New York 2020-03-04     11            9
# 4  New York 2020-03-05     22           11

# %%
import matplotlib.dates as mdates
months = mdates.MonthLocator()
def pltfunc2(x,y,data,xlabel=None,title=None):
    fig, ax = plt.subplots()
    _=ax.plot(x,y,data =data)
    ax.xaxis.set_major_locator(months)
    ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
    ax.format_ydata = lambda x: '$%1.2f' % x  # format the price.
    ax.grid(True)

    # rotates and right aligns the x labels, and moves the bottom of the
    # axes up to make room for them
    fig.autofmt_xdate()
    _=plt.xlabel(xlabel)
    _=plt.title(title)
    
# pltfunc2('date', 'confirmed_cases', usc,"Date from 2020-01-22 to 2020-06-07")

# %%
def daily_cases_func(statelist):
    k = statelist.groupby(['state','date']).cases.sum()
    k = k.reset_index()
    k['date'] = pd.to_datetime(k.date)
    dt = k.cases
    lst = []
    for i in range(len(k)-1,0,-1):
        lst.append(dt[i]-dt[i-1])
    lst.append(1)
    k['daily_cases'] = lst[::-1]
    return k
daily_cases_func(k)
# Out:
#        state       date   cases  daily_cases
# 0   New York 2020-03-01       1            1
# 1   New York 2020-03-02       1            0
# 2   New York 2020-03-03       2            1
# 3   New York 2020-03-04      11            9
# 4   New York 2020-03-05      22           11
# ..       ...        ...     ...          ...
# 93  New York 2020-06-02  377881         1361
# 94  New York 2020-06-03  378924         1043
# 95  New York 2020-06-04  379977         1053
# 96  New York 2020-06-05  381019         1042
# 97  New York 2020-06-06  382102         1083
#
# [98 rows x 4 columns]

# %%
import matplotlib.dates as mdates
months = mdates.MonthLocator()
fig, ax = plt.subplots(2,2,figsize=(12,9))
color = ['blue','orange','green','red','purple']
for j in range(0,5):
    statelist = df1[df1.state==slst[j]]
    k = daily_cases_func(statelist)
    if j == 0:
        t = 'ax[0,0]'
    elif j ==1:
        t = 'ax[0,1]'
    elif j == 2:
        t = 'ax[1,0]'
    elif j == 3:
        t = 'ax[1,1]'
    else:
        fig, ax = plt.subplots()
        t = 'ax'
    p = eval(t)
    p.plot('date', 'daily_cases',data =k,color=color[j])
    p.format_xdata = mdates.DateFormatter('%Y-%m-%d')
    #p.format_ydata = lambda x: '$%1.2f' % x  # format the price.
    p.grid(True)
    fig.autofmt_xdate()
    p.set_title(slst[j])
    

#pltfunc2('date', 'daily_cases', k,title = j)

# %%
fig, ax = plt.subplots(figsize=(12, 9))
for j in range(len(slst)):
    statelist = df1[df1.state==slst[j]]
    k = daily_cases_func(statelist)
    _=ax.scatter('date', 'daily_cases',data =k)
    _=ax.plot('date', 'daily_cases',data =k, color = color[j])
ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
ax.format_ydata = lambda x: '$%1.2f' % x  # format the price.
ax.grid(True)
fig.autofmt_xdate()

# %%
k = daily_cases_func( df1[df1.state==slst[0]])
for j in range(1,5):
    statelist = df1[df1.state==slst[j]]
    k = k.append(daily_cases_func(statelist))
fivestatesconfirm =k
fivestatesconfirm.describe()
# Out:
#                cases   daily_cases
# count     589.000000    589.000000
# mean    68572.227504   1537.393888
# std     96105.057495   2017.800429
# min         1.000000      0.000000
# 25%        81.000000     15.000000
# 50%     28142.000000   1100.000000
# 75%     97017.000000   2078.000000
# max    382102.000000  12237.000000

# %%
fivestatesconfirm.state.unique()
# Out:
# array(['New York', 'New Jersey', 'California', 'Illinois',
#        'Massachusetts'], dtype=object)

# %% [markdown]
# ## Global_Mobility_Report data preprocessing

# %%
dt2.head(3)
# Out:
#   country_region_code        country_region sub_region_1 sub_region_2  \
# 0                  AE  United Arab Emirates          NaN          NaN
# 1                  AE  United Arab Emirates          NaN          NaN
# 2                  AE  United Arab Emirates          NaN          NaN
#
#          date  retail_and_recreation_percent_change_from_baseline  \
# 0  2020-02-15                                                0.0
# 1  2020-02-16                                                1.0
# 2  2020-02-17                                               -1.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                4.0
# 1                                                4.0
# 2                                                1.0
#
#    parks_percent_change_from_baseline  \
# 0                                 5.0
# 1                                 4.0
# 2                                 5.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            0.0
# 1                                            1.0
# 2                                            1.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      2.0
# 1                                      2.0
# 2                                      2.0
#
#    residential_percent_change_from_baseline
# 0                                       1.0
# 1                                       1.0
# 2                                       1.0

# %%
usm = dt2[dt2['country_region']=='United States']
usm.head(3)
# Out:
#        country_region_code country_region sub_region_1 sub_region_2  \
# 184064                  US  United States          NaN          NaN
# 184065                  US  United States          NaN          NaN
# 184066                  US  United States          NaN          NaN
#
#               date  retail_and_recreation_percent_change_from_baseline  \
# 184064  2020-02-15                                                6.0
# 184065  2020-02-16                                                7.0
# 184066  2020-02-17                                                6.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 184064                                                2.0
# 184065                                                1.0
# 184066                                                0.0
#
#         parks_percent_change_from_baseline  \
# 184064                                15.0
# 184065                                16.0
# 184066                                28.0
#
#         transit_stations_percent_change_from_baseline  \
# 184064                                            3.0
# 184065                                            2.0
# 184066                                           -9.0
#
#         workplaces_percent_change_from_baseline  \
# 184064                                      2.0
# 184065                                      0.0
# 184066                                    -24.0
#
#         residential_percent_change_from_baseline
# 184064                                      -1.0
# 184065                                      -1.0
# 184066                                       5.0

# %%
usm.sub_region_1.unique()
# Out:
# array([nan, 'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
ca = usm[usm.sub_region_1=='California']
ca.tail()
# Out:
#        country_region_code country_region sub_region_1 sub_region_2  \
# 206793                  US  United States   California  Yuba County
# 206794                  US  United States   California  Yuba County
# 206795                  US  United States   California  Yuba County
# 206796                  US  United States   California  Yuba County
# 206797                  US  United States   California  Yuba County
#
#               date  retail_and_recreation_percent_change_from_baseline  \
# 206793  2020-05-25                                               21.0
# 206794  2020-05-26                                               23.0
# 206795  2020-05-27                                               21.0
# 206796  2020-05-28                                               20.0
# 206797  2020-05-29                                               20.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 206793                                               20.0
# 206794                                               11.0
# 206795                                               14.0
# 206796                                               17.0
# 206797                                               17.0
#
#         parks_percent_change_from_baseline  \
# 206793                                 NaN
# 206794                                 NaN
# 206795                                 NaN
# 206796                                 NaN
# 206797                                94.0
#
#         transit_stations_percent_change_from_baseline  \
# 206793                                          -26.0
# 206794                                           -9.0
# 206795                                          -15.0
# 206796                                          -12.0
# 206797                                          -10.0
#
#         workplaces_percent_change_from_baseline  \
# 206793                                    -66.0
# 206794                                    -30.0
# 206795                                    -31.0
# 206796                                    -31.0
# 206797                                    -27.0
#
#         residential_percent_change_from_baseline
# 206793                                      15.0
# 206794                                       9.0
# 206795                                       9.0
# 206796                                       9.0
# 206797                                      10.0

# %%
usm = usm.rename(columns={'sub_region_1':'state'})

# %%
usm = round(usm.groupby(['state','date']).mean(),2)
usm = usm.reset_index()
#usm = usm.rename(columns={'country_region_code':'Country'})
usm.head()
# Out:
#      state        date  retail_and_recreation_percent_change_from_baseline  \
# 0  Alabama  2020-02-15                                               5.16
# 1  Alabama  2020-02-16                                              -1.45
# 2  Alabama  2020-02-17                                              -1.17
# 3  Alabama  2020-02-18                                              -4.28
# 4  Alabama  2020-02-19                                               1.44
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               0.23
# 1                                              -4.02
# 2                                              -4.48
# 3                                              -5.00
# 4                                              -0.73
#
#    parks_percent_change_from_baseline  \
# 0                               49.57
# 1                               -5.48
# 2                               12.93
# 3                              -12.47
# 4                                6.67
#
#    transit_stations_percent_change_from_baseline  \
# 0                                           5.76
# 1                                           2.14
# 2                                           5.73
# 3                                          -0.68
# 4                                           3.71
#
#    workplaces_percent_change_from_baseline  \
# 0                                     0.78
# 1                                    -1.92
# 2                                   -16.26
# 3                                     0.34
# 4                                     1.40
#
#    residential_percent_change_from_baseline
# 0                                     -0.86
# 1                                      0.52
# 2                                      4.33
# 3                                      1.44
# 4                                      0.00

# %%
usm['date']=pd.to_datetime(usm.date)
usm.head(3)
# Out:
#      state       date  retail_and_recreation_percent_change_from_baseline  \
# 0  Alabama 2020-02-15                                               5.16
# 1  Alabama 2020-02-16                                              -1.45
# 2  Alabama 2020-02-17                                              -1.17
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               0.23
# 1                                              -4.02
# 2                                              -4.48
#
#    parks_percent_change_from_baseline  \
# 0                               49.57
# 1                               -5.48
# 2                               12.93
#
#    transit_stations_percent_change_from_baseline  \
# 0                                           5.76
# 1                                           2.14
# 2                                           5.73
#
#    workplaces_percent_change_from_baseline  \
# 0                                     0.78
# 1                                    -1.92
# 2                                   -16.26
#
#    residential_percent_change_from_baseline
# 0                                     -0.86
# 1                                      0.52
# 2                                      4.33

# %%
slst = ['New York', 'New Jersey','California','Illinois','Massachusetts']
fivedf = usm[usm.state.isin(slst)]
len(fivedf),len(fivestatesconfirm)
# Out:
# (525, 589)

# %% [markdown]
# ## Merge 2 datasets

# %%
df =pd.merge(fivedf,fivestatesconfirm,how='inner',on=['state','date'])

# %%
df.head()
# Out:
#         state       date  retail_and_recreation_percent_change_from_baseline  \
# 0  California 2020-02-15                                               6.34
# 1  California 2020-02-16                                              14.07
# 2  California 2020-02-17                                              11.57
# 3  California 2020-02-18                                               2.70
# 4  California 2020-02-19                                               2.95
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               4.50
# 1                                               7.25
# 2                                               1.73
# 3                                               2.35
# 4                                               1.57
#
#    parks_percent_change_from_baseline  \
# 0                               30.73
# 1                               55.51
# 2                               60.56
# 3                               24.90
# 4                               20.98
#
#    transit_stations_percent_change_from_baseline  \
# 0                                           5.36
# 1                                           6.72
# 2                                          -6.07
# 3                                           3.44
# 4                                           1.10
#
#    workplaces_percent_change_from_baseline  \
# 0                                    -1.76
# 1                                    -0.69
# 2                                   -38.47
# 3                                    -1.33
# 4                                    -1.53
#
#    residential_percent_change_from_baseline  cases  daily_cases
# 0                                     -0.60      7            0
# 1                                     -1.39      7            0
# 2                                      7.49      7            0
# 3                                     -0.06      7            0
# 4                                      0.19      7            0

# %%
df.shape
# Out:
# (492, 10)

# %%
df.describe()
# Out:
#        retail_and_recreation_percent_change_from_baseline  \
# count                                         492.000000
# mean                                          -28.831667
# std                                            22.225427
# min                                           -74.640000
# 25%                                           -44.415000
# 50%                                           -36.480000
# 75%                                           -15.782500
# max                                            26.640000
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# count                                         492.000000
# mean                                           -4.650955
# std                                            13.507768
# min                                           -51.850000
# 25%                                           -13.637500
# 50%                                            -4.685000
# 75%                                             3.540000
# max                                            40.740000
#
#        parks_percent_change_from_baseline  \
# count                          492.000000
# mean                            22.139776
# std                             42.298947
# min                            -58.340000
# 25%                            -10.422500
# 50%                             16.120000
# 75%                             46.247500
# max                            169.310000
#
#        transit_stations_percent_change_from_baseline  \
# count                                     492.000000
# mean                                      -29.908679
# std                                        20.693681
# min                                       -65.690000
# 25%                                       -46.465000
# 50%                                       -34.090000
# 75%                                       -14.600000
# max                                        15.900000
#
#        workplaces_percent_change_from_baseline  \
# count                               492.000000
# mean                                -31.649919
# std                                  20.174944
# min                                 -74.500000
# 25%                                 -46.650000
# 50%                                 -37.685000
# 75%                                 -21.057500
# max                                   5.500000
#
#        residential_percent_change_from_baseline          cases   daily_cases
# count                                492.000000     492.000000    492.000000
# mean                                  13.245955   67723.164634   1732.298780
# std                                    8.524906   93276.987263   2119.280745
# min                                   -3.330000       1.000000      0.000000
# 25%                                    7.440000     418.250000    106.000000
# 50%                                   14.950000   31526.000000   1258.500000
# 75%                                   19.722500   92457.500000   2210.000000
# max                                   30.730000  373108.000000  12237.000000

# %%
df.var()
# Out:
# retail_and_recreation_percent_change_from_baseline    4.939696e+02
# grocery_and_pharmacy_percent_change_from_baseline     1.824598e+02
# parks_percent_change_from_baseline                    1.789201e+03
# transit_stations_percent_change_from_baseline         4.282284e+02
# workplaces_percent_change_from_baseline               4.070284e+02
# residential_percent_change_from_baseline              7.267402e+01
# cases                                                 8.700596e+09
# daily_cases                                           4.491351e+06
# dtype: float64

# %%
df.state.unique()
# Out:
# array(['California', 'Illinois', 'Massachusetts', 'New Jersey',
#        'New York'], dtype=object)

# %%
df.columns
# Out:
# Index(['state', 'date', 'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline', 'cases', 'daily_cases'],
#       dtype='object')

# %%
df.columns =['state', 'date', 
       'retail_and_recreation','grocery_and_pharmacy',
       'parks','transit_stations','workplaces','residential','cumulated_cases','new_cases']
df.head()
# Out:
#         state       date  retail_and_recreation  grocery_and_pharmacy  parks  \
# 0  California 2020-02-15                   6.34                  4.50  30.73
# 1  California 2020-02-16                  14.07                  7.25  55.51
# 2  California 2020-02-17                  11.57                  1.73  60.56
# 3  California 2020-02-18                   2.70                  2.35  24.90
# 4  California 2020-02-19                   2.95                  1.57  20.98
#
#    transit_stations  workplaces  residential  cumulated_cases  new_cases
# 0              5.36       -1.76        -0.60                7          0
# 1              6.72       -0.69        -1.39                7          0
# 2             -6.07      -38.47         7.49                7          0
# 3              3.44       -1.33        -0.06                7          0
# 4              1.10       -1.53         0.19                7          0

# %%
df1 = df.groupby(['date']).mean().reset_index()
df1.head()
# Out:
#         date  retail_and_recreation  grocery_and_pharmacy      parks  \
# 0 2020-02-15               5.756667              1.523333  15.946667
# 1 2020-02-16              10.443333              2.550000  27.443333
# 2 2020-02-17               7.830000             -0.743333  30.100000
# 3 2020-02-18               0.240000             -2.210000   3.370000
# 4 2020-02-19               2.813333             -0.806667   9.603333
#
#    transit_stations  workplaces  residential  cumulated_cases  new_cases
# 0          4.486667   -0.476667    -0.576667         3.333333        0.0
# 1          4.040000    0.650000    -1.093333         3.333333        0.0
# 2         -9.836667  -32.220000     7.016667         3.333333        0.0
# 3          0.326667   -2.636667     1.120000         3.333333        0.0
# 4          0.230000   -2.480000     0.723333         3.333333        0.0

# %%
cor = df1.iloc[:,1:].corr()
cor
# Out:
#                        retail_and_recreation  grocery_and_pharmacy     parks  \
# retail_and_recreation               1.000000              0.761730  0.275798
# grocery_and_pharmacy                0.761730              1.000000  0.363193
# parks                               0.275798              0.363193  1.000000
# transit_stations                    0.985570              0.730064  0.296426
# workplaces                          0.904389              0.673409  0.207495
# residential                        -0.897549             -0.637860 -0.307498
# cumulated_cases                    -0.499563             -0.282471  0.355983
# new_cases                          -0.882963             -0.718253 -0.261367
#
#                        transit_stations  workplaces  residential  \
# retail_and_recreation          0.985570    0.904389    -0.897549
# grocery_and_pharmacy           0.730064    0.673409    -0.637860
# parks                          0.296426    0.207495    -0.307498
# transit_stations               1.000000    0.938222    -0.928759
# workplaces                     0.938222    1.000000    -0.977685
# residential                   -0.928759   -0.977685     1.000000
# cumulated_cases               -0.493076   -0.555802     0.488338
# new_cases                     -0.882749   -0.822610     0.819616
#
#                        cumulated_cases  new_cases
# retail_and_recreation        -0.499563  -0.882963
# grocery_and_pharmacy         -0.282471  -0.718253
# parks                         0.355983  -0.261367
# transit_stations             -0.493076  -0.882749
# workplaces                   -0.555802  -0.822610
# residential                   0.488338   0.819616
# cumulated_cases               1.000000   0.460178
# new_cases                     0.460178   1.000000

# %%
f, ax = plt.subplots(figsize=(12, 9))
hm = sns.heatmap(round(cor,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f',
                 linewidths=.05)
f.subplots_adjust(top=0.93)
t= f.suptitle('Moblitiy rate and Covid-19 cases correlation in USA', fontsize=14)

# %%
import matplotlib.dates as mdates
months = mdates.MonthLocator()
color = ['blue','orange','green','red','purple']

# %%
_ = plt.plot(range(0,97),df['grocery_and_pharmacy'])
_ = plt.title('grocery_and_pharmacy')
_ = plt.xlabel("Date from 2020-02-15 to 2020-05-28")
_ = plt.ylabel("percentage")

# %%
_ = plt.plot(range(0,97),df['parks'])
_ = plt.title('parks')
_ = plt.xlabel("Date from 2020-02-15 to 2020-05-28")
_ = plt.ylabel("percentage")

# %%
_ = plt.plot(range(0,97),df['transit_stations'])
_ = plt.title('transit_stations')
_ = plt.xlabel("Date from 2020-02-15 to 2020-05-28")
_ = plt.ylabel("percentage")

# %%
_ = plt.plot(range(0,97),df['workplaces'])
_ = plt.title('workplaces')
_ = plt.xlabel("Date from 2020-02-15 to 2020-05-28")
_ = plt.ylabel("percentage")

# %%
_ = plt.plot(range(0,97),df['residential'])
_ = plt.title('residential')
_ = plt.xlabel("Date from 2020-02-15 to 2020-05-28")
_ = plt.ylabel("percentage")

# %%
df.to_csv('processed_dt')
