# %%
import pandas as pd 
import matplotlib.dates as mdates
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('processed_dt',index_col=0)
df.shape
# Out:
# (492, 10)

# %%
df.head()
# Out:
#         state        date  retail_and_recreation  grocery_and_pharmacy  parks  \
# 0  California  2020-02-15                   6.34                  4.50  30.73
# 1  California  2020-02-16                  14.07                  7.25  55.51
# 2  California  2020-02-17                  11.57                  1.73  60.56
# 3  California  2020-02-18                   2.70                  2.35  24.90
# 4  California  2020-02-19                   2.95                  1.57  20.98
#
#    transit_stations  workplaces  residential  cumulated_cases  new_cases
# 0              5.36       -1.76        -0.60                7          0
# 1              6.72       -0.69        -1.39                7          0
# 2             -6.07      -38.47         7.49                7          0
# 3              3.44       -1.33        -0.06                7          0
# 4              1.10       -1.53         0.19                7          0

# %%
df.date =pd.to_datetime(df.date)

# %%
len(tempdf.iloc[:,9])
# Out:
# 90

# %%
months = mdates.MonthLocator()
color = ['blue','orange','green','red','purple']

# %%
slst= list(df.state.unique())
fig, ax = plt.subplots(figsize=(9, 7))
for j in range(len(slst)):
    statelist = df[df.state==slst[j]]
    #_=ax.scatter('date', 'daily_cases',data =k)
    _=ax.plot('date','retail_and_recreation',data =statelist, color = color[j])
ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
ax.format_ydata = lambda x: '$%1.2f' % x  # format the price.
ax.grid(True)
fig.autofmt_xdate()
_=ax.set_title('Retail_and_recreation')
_=ax.set_ylabel('Percentage')

# %%
fig, ax = plt.subplots(1,2,figsize=(11, 9))
for i in range(2):
    for j in range(len(slst1)):
        statelist = df[df.state==slst1[j]]
        #_=ax.scatter('date', 'daily_cases',data =k)
        if i==0:
            ax[i].plot('date','retail_and_recreation',data =statelist, color = color[j])
        else:
            ax[i].scatter('new_cases','retail_and_recreation',data =statelist, color = color[j])
    ax[i].format_xdata = mdates.DateFormatter('%Y-%m-%d')
    ax[i].format_ydata = lambda x: '$%1.2f' % x  # format the price.
    ax[i].grid(True)
    fig.autofmt_xdate()
    ax[i].set_title('Retail_and_recreation')
    ax[i].set_ylabel('Percentage')
_=ax[i].set_xlabel('New_cases')

# %%
fig, ax = plt.subplots(1,2,figsize=(11, 9))
for i in range(2):
    for j in range(len(slst1)):
        statelist = df[df.state==slst1[j]]
        #_=ax.scatter('date', 'daily_cases',data =k)
        if i==0:
            ax[i].plot('date','grocery_and_pharmacy',data =statelist, color = color[j])
        else:
            ax[i].scatter('new_cases','grocery_and_pharmacy',data =statelist, color = color[j])
    ax[i].format_xdata = mdates.DateFormatter('%Y-%m-%d')
    ax[i].format_ydata = lambda x: '$%1.2f' % x  # format the price.
    ax[i].grid(True)
    fig.autofmt_xdate()
    ax[i].set_title('Grocery_and_pharmacy')
    ax[i].set_ylabel('Percentage')
_=ax[i].set_xlabel('New_cases')

# %%
fig, ax = plt.subplots(1,2,figsize=(11, 9))
for i in range(2):
    for j in range(len(slst1)):
        statelist = df[df.state==slst1[j]]
        #_=ax.scatter('date', 'daily_cases',data =k)
        if i==0:
            ax[i].plot('date','parks',data =statelist, color = color[j])
        else:
            ax[i].scatter('new_cases','workplaces',data =statelist, color = color[j])
    ax[i].format_xdata = mdates.DateFormatter('%Y-%m-%d')
    ax[i].format_ydata = lambda x: '$%1.2f' % x  # format the price.
    ax[i].grid(True)
    fig.autofmt_xdate()
    ax[i].set_title('Parks')
    ax[i].set_ylabel('Percentage')
_=ax[i].set_xlabel('New_cases')

# %%
fig, ax = plt.subplots(1,2,figsize=(11, 9))
for i in range(2):
    for j in range(len(slst1)):
        statelist = df[df.state==slst1[j]]
        #_=ax.scatter('date', 'daily_cases',data =k)
        if i==0:
            ax[i].plot('date','transit_stations',data =statelist, color = color[j])
        else:
            ax[i].scatter('new_cases','transit_stations',data =statelist, color = color[j])
    ax[i].format_xdata = mdates.DateFormatter('%Y-%m-%d')
    ax[i].format_ydata = lambda x: '$%1.2f' % x  # format the price.
    ax[i].grid(True)
    fig.autofmt_xdate()
    ax[i].set_title('Transit_stations')
    ax[i].set_ylabel('Percentage')
_=ax[i].set_xlabel('New_cases')

# %%
fig, ax = plt.subplots(1,2,figsize=(11, 9))
for i in range(2):
    for j in range(len(slst1)):
        statelist = df[df.state==slst1[j]]
        #_=ax.scatter('date', 'daily_cases',data =k)
        if i==0:
            ax[i].plot('date','workplaces',data =statelist, color = color[j])
        else:
            ax[i].scatter('new_cases','workplaces',data =statelist, color = color[j])
    ax[i].format_xdata = mdates.DateFormatter('%Y-%m-%d')
    ax[i].format_ydata = lambda x: '$%1.2f' % x  # format the price.
    ax[i].grid(True)
    fig.autofmt_xdate()
    ax[i].set_title('workplaces')
    ax[i].set_ylabel('Percentage')
_=ax[i].set_xlabel('New_cases')

# %%
fig, ax = plt.subplots(1,2,figsize=(11, 9))
for i in range(2):
    for j in range(len(slst1)):
        statelist = df[df.state==slst1[j]]
        #_=ax.scatter('date', 'daily_cases',data =k)
        if i==0:
            ax[i].plot('date','residential',data =statelist, color = color[j])
        else:
            ax[i].scatter('new_cases','residential',data =statelist, color = color[j])
    ax[i].format_xdata = mdates.DateFormatter('%Y-%m-%d')
    ax[i].format_ydata = lambda x: '$%1.2f' % x  # format the price.
    ax[i].grid(True)
    fig.autofmt_xdate()
    ax[i].set_title('Residential')
    ax[i].set_ylabel('Percentage')
_=ax[i].set_xlabel('New_cases')
